# %%
from datasets import load_dataset

dataset = load_dataset("simecek/czech_news")
dataset
# Out:
# ...
# DatasetDict({
#     train: Dataset({
#         features: ['url', 'authors', 'headline', 'brief', 'keywords', 'category', 'content', 'comments_num', 'server', 'category_unclean', 'authors_gender', 'authors_cum_gender', 'day_of_week', 'date', '__index_level_0__', '__index_level_1__', 'system_prompt', 'user_prompt'],
#         num_rows: 1000
#     })
# })

# %%
dataset.save_to_disk("data/czech_news")
# Out:
# {'url': 'https://www.irozhlas.cz/ekonomika/citibank-okd-pohledavky-platne-insolvencni-soud_2109221437_tzr',
#  'authors': [],
#  'headline': 'Soud potvrdil platnost pohledávek Citibank za OKD za 10 miliard korun. Rozhodnutí je nepravomocné',
#  'brief': 'Pohledávky za více než deset miliard korun, které za společností OKD přihlásila v roce 2016 britská banka Citibank, jsou oprávněné. Ve středu o tom opět rozhodl Insolvenční soud v Ostravě. Rozhodnutí ale zatím není pravomocné a je možné, že stejně jako po prvním rozsudku v roce 2019 přijde odvolání',
#  'keywords': ['Okd',
#   'Citibank',
#   'Pohledávky',
#   'Ostrava',
#   'Soud',
#   'Pohledávka'],
#  'category': 5,
# ...

# %%
dataset['train'][0]
new_dataset = []

for i in range(len(dataset["train"])):
    article = dataset['train'][i]
    full = article["headline"] + article["headline"] + article["brief"] + article["brief"] + article["content"]
    new_dataset.append(full)
